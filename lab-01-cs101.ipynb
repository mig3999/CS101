# %% [markdown]
# ![Screenshot 2024-08-29 at 7.39.27 PM.png](attachment:2f43d682-0154-41f4-ad60-7fdccb14ebaa.png)
#
# # Lab 1 - Aug 30, 2024

# %% [markdown]
# ### Welcome to Jupyter.
#
# Mr. Borges loves Jupyter.  He uses it for everything.
#
# ![jupyter.jpg](attachment:7e9272a4-9a83-4f39-9f8d-5da2f1b8795b.jpg)
#
# Hopefully you'll learn to love Jupyter too.

# %% [markdown]
# Jupyter works with "cells" which are these squares that can have text (in Markdown format) or code (usually Python) inside of them.  For example, the next cell has a simple Python program.  Click on the next cell and press the Play button (looks like a triangle) to run it.

# %%
# this is a python program that will find all the prime numbers between 1 and 50
# press the "run" button to run it.  The output will display below the cell.

for x in range (1,50):
    status = True
    for y in range (2,x):
        if (x % y) == 0:
            status = False
    if (status == True):
        print (x)

# %% [markdown]
# Now try copying and pasting that code above into the blank cell below, and then run it.
# If it works, great.
#
# Modify the code so that it finds all the prime numbers between 1 and 100.  How about 1 and 10000?
#
# Can you think of an easy way to modify your algorithm so that it runs twices as fast?

# %%
# copy the code into this cell and run it / make changes.

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# ## finished!
#
# When you're all done, you can submit this finished lab activity as a PDF file.
#
# Like in this photo:
#
# ![arrow2.jpg](attachment:67b3b2fa-c6f6-4fb6-a0a7-529eefc49c93.jpg)
#
# Do this now!  Submit it!  You're finished!
