# %% [markdown]
# ![Screenshot 2024-10-03 at 7.27.26 PM.png](attachment:3af6dfb7-26ef-45c0-85e4-f2f1ad661ea9.png)
#
# ### Lab Assignment 8

# %% [markdown]
# ## Question #1
#
# Write a python program that prompts the user to enter a year and then determines whether it's a leap year.
#
# * If the year is evenly divisible by 4, go to step 2. Otherwise, go to step 5.
# * If the year is evenly divisible by 100, go to step 3. Otherwise, go to step 4.
# * If the year is evenly divisible by 400, go to step 4. Otherwise, go to step 5.
# * The year is a leap year (it has 366 days).
# * The year is not a leap year (it has 365 days).

# %%
# Write your Python program here.

# %% [markdown]
# &nbsp;
#
# ## Question #2
#
# Create a multiple-choice quiz program with questions and predefined answers. Use boolean logic to evaluate whether the user's selected answer is correct and keep track of their score.  Your quiz should have 3 or 4 questions on a common theme.

# %%
# Question #2 response in here

# %% [markdown]
# &nbsp;
#
# ## Question #3
#
# Develop a simple text-based Rock, Paper, Scissors game. The program should take user input and randomly select a choice for the computer, then determine the winner using boolean logic.

# %%
# Rock Paper Scissors
