# %% [markdown]
# ![Screenshot 2024-09-19 at 8.11.44 PM.png](attachment:855f6592-fec6-4e51-bd68-5b870d8a67a0.png)
# ### Lab Assignment 5

# %% [markdown]
# In Python, we can ask the user for input like this:

# %%
binaryString = input("what is your binary string? ")
print ("your string is ",binaryString)
# Out:
# what is your binary string?  000200201

# %% [markdown]
# And we can iterate through a string using a for loop like this:

# %%
myString = "01011101"
for x in myString:
    print (x)

# %% [markdown]
# What's happening above is that we will step (iterate) through the myString variable and for each *character* in the *string* ... so that x is a different *character* each time we go through the loop.
#
# Now that we know how to do both of these things, we can do this:
#
# ## Question 1
#
# Write a python program in the cell below that will ask the user for a binary number, store it as a string, then iterate through that string and convert it to a decimal number.

# %%
# question 1 python program in here

# %% [markdown]
# &nbsp;
#
# ## Question 2
#
# Write a python program that will take an input as a decimal number, and convert it into a binary string.  Hint:  you'll want to convert whatever the use types in (a string) into a number first.

# %%
# question 2 here

# %% [markdown]
# ## Question 3
#
# Now let's try something more difficult.  Have the user type in a word or phrase, and convert it into binary.  You'll want to convert each character of the input into the ASCII number, and then find the binary of that number.  You can use the ``ord()`` function to do this.

# %%
# question 3 here
